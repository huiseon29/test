# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from matplotlib import font_manager, rc
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from scipy.stats.mstats import winsorize
from sklearn.preprocessing import StandardScaler

# 한글 폰트 설정
font_path = "C:/Windows/Fonts/malgun.ttf"  # 한글 폰트 파일 경로
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# 경고 메시지 무시
warnings.filterwarnings('ignore')

# %%
from scipy.stats import norm
from scipy import stats
from statsmodels.formula.api import ols
from scipy.stats import kstest

# %%
col_list = ['총자본증가율', '유형자산증가율', '유동자산증가율',
       '재고자산증가율', '자기자본증가율', '매출액증가율', '매출액정상영업이익률', '매출액순이익률', '자기자본순이익률',
       '자본금순이익률', '기업순이익률', '매출원가 대 매출액비율', '금융비용 대 총비용비율', '감가상각률',
       '차입금평균이자율', '사내유보율', '평균배당률', '자기자본배당률', '배당성향', '자기자본구성비율', '비유동비율',
       '비유동장기적합률', '유동비율', '당좌비율', '현금비율', '매출채권 대 매입채무비율', '부채비율', '유동부채비율',
       '비유동부채비율', '차입금의존도', '자기자본회전률', '자본금회전률', '매입채무회전률', '재고자산회전률',
       '비유동자산회전률', '유형자산회전율', '총자본투자효율', '설비투자효율', '기계투자효율', '부가가치율',
       '노동소득분배율', '인건비(백만원)', '금융비용(백만원)', '임차료(백만원)', '세금과공과(백만원)',
       '감가상각비(백만원)', '부채대비영업활동현금흐름', '자본대비영업활동현금흐름', '매출액대비영업활동현금흐름',
       '3년지수가중평균매출액', '업력', '연 변동성', 'PER', 'PBR', 'label']

num_list = ['총자본증가율', '유형자산증가율', '유동자산증가율',
       '재고자산증가율', '자기자본증가율', '매출액증가율', '매출액정상영업이익률', '매출액순이익률', '자기자본순이익률',
       '자본금순이익률', '기업순이익률', '매출원가 대 매출액비율', '금융비용 대 총비용비율', '감가상각률',
       '차입금평균이자율', '사내유보율', '평균배당률', '자기자본배당률', '배당성향', '자기자본구성비율', '비유동비율',
       '비유동장기적합률', '유동비율', '당좌비율', '현금비율', '매출채권 대 매입채무비율', '부채비율', '유동부채비율',
       '비유동부채비율', '차입금의존도', '자기자본회전률', '자본금회전률', '매입채무회전률', '재고자산회전률',
       '비유동자산회전률', '유형자산회전율', '총자본투자효율', '설비투자효율', '기계투자효율', '부가가치율',
       '노동소득분배율', '인건비(백만원)', '금융비용(백만원)', '임차료(백만원)', '세금과공과(백만원)',
       '감가상각비(백만원)', '부채대비영업활동현금흐름', '자본대비영업활동현금흐름', '매출액대비영업활동현금흐름',
       '3년지수가중평균매출액', '업력', '연 변동성', 'PER', 'PBR']

# %%
df_scaled = pd.read_csv('../datasets/상장_train.csv', index_col = 0)[col_list]

# %% [markdown]
# ### T-test(K-S통계량 검정)

# %%
for j in num_list:
    a = kstest(df_scaled[j],'norm')
    p = a.pvalue
    print(j,a)
# Out:
# 총자본증가율 KstestResult(statistic=0.11264414300953457, pvalue=3.9922680706383875e-69, statistic_location=-0.5519332827899924, statistic_sign=-1)
# 유형자산증가율 KstestResult(statistic=0.16443068781444498, pvalue=2.883965934858779e-147, statistic_location=-0.4544854881266491, statistic_sign=-1)
# 유동자산증가율 KstestResult(statistic=0.08911376509742508, pvalue=2.2150522237163804e-43, statistic_location=-0.4638748274275195, statistic_sign=-1)
# 재고자산증가율 KstestResult(statistic=0.1301842091016855, pvalue=2.8747646593591663e-92, statistic_location=-0.3485148514851485, statistic_sign=-1)
# 자기자본증가율 KstestResult(statistic=0.11969864099430577, pvalue=5.017867199418247e-78, statistic_location=-0.4562398703403565, statistic_sign=-1)
# 매출액증가율 KstestResult(statistic=0.0960851292085082, pvalue=2.2356762768636247e-50, statistic_location=-0.482233502538071, statistic_sign=-1)
# 매출액정상영업이익률 KstestResult(statistic=0.1212193071164864, pvalue=5.130850204553097e-80, statistic_location=-0.5768772348033373, statistic_sign=-1)
# 매출액순이익률 KstestResult(statistic=0.09965532409988934, pvalue=3.639510441075784e-54, statistic_location=-0.474009900990099, statistic_sign=-1)
# 자기자본순이익률 KstestResult(statistic=0.06623678696773924, pvalue=3.830175317501138e-24, statistic_location=-0.5724070450097848, statistic_sign=-1)
# 자본금순이익률 KstestResult(statistic=0.1619575502022877, pvalue=7.402199617520356e-143, statistic_location=-0.4726183095680926, statistic_sign=-1)
# 기업순이익률 KstestResult(statistic=0.07599873614946634, pvalue=1.1764604612419034e-31, statistic_location=-0.4658901830282861, statistic_sign=-1)
# 매출원가 대 매출액비율 KstestResult(statistic=0.20036834753853738, pvalue=4.1409049813078584e-219, statistic_location=0.7053872053872049, statistic_sign=1)
# 금융비용 대 총비용비율 KstestResult(statistic=0.08749129578548198, pvalue=7.89768332956032e-42, statistic_location=-0.5116279069767442, statistic_sign=-1)
# 감가상각률 KstestResult(statistic=0.14149401252583002, pvalue=5.445460661953718e-109, statistic_location=-0.7182705718270573, statistic_sign=-1)
# 차입금평균이자율 KstestResult(statistic=0.1042860676721638, pvalue=2.7517786528246357e-59, statistic_location=-0.5613207547169812, statistic_sign=-1)
# 사내유보율 KstestResult(statistic=0.5, pvalue=0.0, statistic_location=0.0, statistic_sign=-1)
# 평균배당률 KstestResult(statistic=0.35283911655955114, pvalue=0.0, statistic_location=-0.3776666666666666, statistic_sign=-1)
# 자기자본배당률 KstestResult(statistic=0.30945021502814685, pvalue=0.0, statistic_location=-0.4974093264248704, statistic_sign=-1)
# 배당성향 KstestResult(statistic=0.3434331882306257, pvalue=0.0, statistic_location=-0.4031112614135949, statistic_sign=-1)
# 자기자본구성비율 KstestResult(statistic=0.1354012583559694, pvalue=8.328595123289965e-100, statistic_location=1.0279809220985687, statistic_sign=1)
# 비유동비율 KstestResult(statistic=0.15176233383885002, pvalue=2.1137177585693634e-125, statistic_location=-0.8472113732229339, statistic_sign=-1)
# 비유동장기적합률 KstestResult(statistic=0.08933413846182467, pvalue=1.35628730875644e-43, statistic_location=-1.0509823427008207, statistic_sign=-1)
# 유동비율 KstestResult(statistic=0.22414355237671382, pvalue=1.0230891585913724e-274, statistic_location=-0.652191303354094, statistic_sign=-1)
# 당좌비율 KstestResult(statistic=0.24620085652693793, pvalue=0.0, statistic_location=-0.6407346001785487, statistic_sign=-1)
# 현금비율 KstestResult(statistic=0.2943041164718405, pvalue=0.0, statistic_location=-0.540853979968371, statistic_sign=-1)
# 매출채권 대 매입채무비율 KstestResult(statistic=0.18745596163266065, pvalue=1.2903145400517265e-191, statistic_location=-0.8873101855963057, statistic_sign=-1)
# 부채비율 KstestResult(statistic=0.25491389922161306, pvalue=0.0, statistic_location=-0.6591058514135437, statistic_sign=-1)
# 유동부채비율 KstestResult(statistic=0.24887304478482186, pvalue=0.0, statistic_location=-0.6780403819064016, statistic_sign=-1)
# 비유동부채비율 KstestResult(statistic=0.3279631345750389, pvalue=0.0, statistic_location=-0.4455445544554455, statistic_sign=-1)
# 차입금의존도 KstestResult(statistic=0.25921169577959446, pvalue=0.0, statistic_location=-0.645777607948032, statistic_sign=-1)
# 자기자본회전률 KstestResult(statistic=0.18181430953699726, pvalue=3.3863533452333195e-180, statistic_location=-0.801470588235294, statistic_sign=-1)
# 자본금회전률 KstestResult(statistic=0.2812040782681646, pvalue=0.0, statistic_location=-0.579268292682927, statistic_sign=-1)
# 매입채무회전률 KstestResult(statistic=0.17971638318398145, pvalue=4.834395365176058e-176, statistic_location=-0.7029629629629629, statistic_sign=-1)
# 재고자산회전률 KstestResult(statistic=0.22773193401321823, pvalue=1.1261383873019743e-283, statistic_location=-0.7463369963369964, statistic_sign=-1)
# 비유동자산회전률 KstestResult(statistic=0.1756324959352395, pvalue=4.261004583596475e-168, statistic_location=-0.8727272727272726, statistic_sign=-1)
# 유형자산회전율 KstestResult(statistic=0.23888379563924034, pvalue=1.805702037294e-312, statistic_location=-0.6207792207792207, statistic_sign=-1)
# 총자본투자효율 KstestResult(statistic=0.0966109095175626, pvalue=6.313169063743178e-51, statistic_location=-0.7643979057591621, statistic_sign=-1)
# 설비투자효율 KstestResult(statistic=0.2016645998352044, pvalue=5.652926342496525e-222, statistic_location=-0.6091991341991342, statistic_sign=-1)
# 기계투자효율 KstestResult(statistic=0.36400604157636124, pvalue=0.0, statistic_location=-0.2511107507702287, statistic_sign=-1)
# 부가가치율 KstestResult(statistic=0.12045104813988543, pvalue=5.234907279972241e-79, statistic_location=-0.7806451612903225, statistic_sign=-1)
# 노동소득분배율 KstestResult(statistic=0.07795866406691948, pvalue=2.7376217311080778e-33, statistic_location=-0.8240680183126227, statistic_sign=-1)
# 인건비(백만원) KstestResult(statistic=0.34745871158901853, pvalue=0.0, statistic_location=-0.3921905537979848, statistic_sign=-1)
# 금융비용(백만원) KstestResult(statistic=0.18245737798505365, pvalue=1.763150248922148e-181, statistic_location=-0.394436837536829, statistic_sign=-1)
# 임차료(백만원) KstestResult(statistic=0.5, pvalue=0.0, statistic_location=0.0, statistic_sign=-1)
# 세금과공과(백만원) KstestResult(statistic=0.5, pvalue=0.0, statistic_location=0.0, statistic_sign=-1)
# 감가상각비(백만원) KstestResult(statistic=0.3833267005216714, pvalue=0.0, statistic_location=-0.2967552126376755, statistic_sign=-1)
# 부채대비영업활동현금흐름 KstestResult(statistic=0.12108000897856208, pvalue=7.826528843089374e-80, statistic_location=-0.6085542685580475, statistic_sign=-1)
# 자본대비영업활동현금흐름 KstestResult(statistic=0.07102276135275243, pvalue=1.0700276431036157e-27, statistic_location=-0.5012252699561441, statistic_sign=-1)
# 매출액대비영업활동현금흐름 KstestResult(statistic=0.08809786580262474, pvalue=2.0921460918269548e-42, statistic_location=-0.5339364610055186, statistic_sign=-1)
# 3년지수가중평균매출액 KstestResult(statistic=0.3667432927394306, pvalue=0.0, statistic_location=-0.3404912839943612, statistic_sign=-1)
# 업력 KstestResult(statistic=0.15865525393145707, pvalue=4.471005627992088e-137, statistic_location=-1.0, statistic_sign=-1)
# 연 변동성 KstestResult(statistic=0.12322555265469486, pvalue=1.1100891705364247e-82, statistic_location=-0.8897430925104649, statistic_sign=-1)
# PER KstestResult(statistic=0.273908806391432, pvalue=0.0, statistic_location=-0.6010335917312661, statistic_sign=-1)
# PBR KstestResult(statistic=0.25655211894914776, pvalue=0.0, statistic_location=-0.5985401459854016, statistic_sign=-1)

# %%
# 부도기업과 정상기업의 피처별 등분산비교 (정규성 가정으로 bartlett)
Bad = df_scaled[df_scaled['label']== 1] #Existing Customer
Good = df_scaled[df_scaled['label']== 0] #Attrited Customer

c = []
for i in df_scaled.drop('label', axis = 1):
    # lresult = stats.levene(close[i], normal[i])
    lresult = stats.bartlett(Bad[i], Good[i])
    c.append([i,lresult[-1]])

c= pd.DataFrame(c)
c.columns=["피처값",'F-test']
c
# Out:
#               피처값         F-test
# 0          총자본증가율   1.568630e-56
# 1         유형자산증가율   2.148733e-47
# 2         유동자산증가율   2.511731e-36
# 3         재고자산증가율   6.706899e-01
# 4         자기자본증가율  1.501459e-123
# 5          매출액증가율   6.404316e-55
# 6      매출액정상영업이익률   0.000000e+00
# 7         매출액순이익률   0.000000e+00
# 8        자기자본순이익률   0.000000e+00
# 9         자본금순이익률   1.726543e-68
# 10         기업순이익률  7.142701e-201
# 11   매출원가 대 매출액비율   1.841786e-01
# 12   금융비용 대 총비용비율  9.014015e-113
# 13          감가상각률   3.272828e-09
# 14       차입금평균이자율   9.197473e-23
# 15          사내유보율   1.661129e-33
# 16          평균배당률  2.268314e-292
# 17        자기자본배당률   1.184798e-77
# 18           배당성향   1.956458e-12
# 19       자기자본구성비율   1.042644e-05
# 20          비유동비율  5.641854e-188
# 21       비유동장기적합률   1.377203e-69
# 22           유동비율   3.483800e-06
# 23           당좌비율   3.225781e-08
# 24           현금비율   4.548902e-02
# 25  매출채권 대 매입채무비율   1.149270e-13
# 26           부채비율  2.570934e-139
# 27         유동부채비율  5.249467e-156
# 28        비유동부채비율   1.108015e-93
# 29         차입금의존도   5.363747e-16
# 30        자기자본회전률   9.283453e-07
# 31         자본금회전률  2.345232e-113
# 32        매입채무회전률   2.074151e-36
# 33        재고자산회전률   8.397081e-72
# 34       비유동자산회전률   4.338679e-08
# 35        유형자산회전율   2.859476e-05
# 36        총자본투자효율   1.510000e-36
# 37         설비투자효율   2.160545e-54
# 38         기계투자효율   5.037434e-59
# 39          부가가치율  3.266884e-254
# 40        노동소득분배율  8.944541e-217
# 41       인건비(백만원)  2.038032e-115
# 42      금융비용(백만원)   2.300090e-10
# 43       임차료(백만원)   3.697088e-31
# 44     세금과공과(백만원)   7.924970e-74
# 45     감가상각비(백만원)  3.103048e-125
# 46   부채대비영업활동현금흐름   4.277293e-27
# 47   자본대비영업활동현금흐름   2.517394e-35
# 48  매출액대비영업활동현금흐름   0.000000e+00
# 49    3년지수가중평균매출액  1.629029e-109
# 50             업력   1.323187e-01
# 51          연 변동성   1.836165e-08
# 52            PER   1.393873e-01
# 53            PBR   1.750194e-51

# %%
# F-test 결과 0.05 이상이면 homo 0.05 이하이면 hetero
c["분산"] =''
c["T-test"] =""
for i in c.index:
    if c.loc[i,"F-test"]>=0.05:
        c.loc[i,"분산"] = "homo"
    else:
        c.loc[i,"분산"] = "hetero"
c
# Out:
#               피처값         F-test      분산 T-test
# 0          총자본증가율   1.568630e-56  hetero
# 1         유형자산증가율   2.148733e-47  hetero
# 2         유동자산증가율   2.511731e-36  hetero
# 3         재고자산증가율   6.706899e-01    homo
# 4         자기자본증가율  1.501459e-123  hetero
# 5          매출액증가율   6.404316e-55  hetero
# 6      매출액정상영업이익률   0.000000e+00  hetero
# 7         매출액순이익률   0.000000e+00  hetero
# 8        자기자본순이익률   0.000000e+00  hetero
# 9         자본금순이익률   1.726543e-68  hetero
# 10         기업순이익률  7.142701e-201  hetero
# 11   매출원가 대 매출액비율   1.841786e-01    homo
# 12   금융비용 대 총비용비율  9.014015e-113  hetero
# 13          감가상각률   3.272828e-09  hetero
# 14       차입금평균이자율   9.197473e-23  hetero
# 15          사내유보율   1.661129e-33  hetero
# 16          평균배당률  2.268314e-292  hetero
# 17        자기자본배당률   1.184798e-77  hetero
# 18           배당성향   1.956458e-12  hetero
# 19       자기자본구성비율   1.042644e-05  hetero
# 20          비유동비율  5.641854e-188  hetero
# 21       비유동장기적합률   1.377203e-69  hetero
# 22           유동비율   3.483800e-06  hetero
# 23           당좌비율   3.225781e-08  hetero
# 24           현금비율   4.548902e-02  hetero
# 25  매출채권 대 매입채무비율   1.149270e-13  hetero
# 26           부채비율  2.570934e-139  hetero
# 27         유동부채비율  5.249467e-156  hetero
# 28        비유동부채비율   1.108015e-93  hetero
# 29         차입금의존도   5.363747e-16  hetero
# 30        자기자본회전률   9.283453e-07  hetero
# 31         자본금회전률  2.345232e-113  hetero
# 32        매입채무회전률   2.074151e-36  hetero
# 33        재고자산회전률   8.397081e-72  hetero
# 34       비유동자산회전률   4.338679e-08  hetero
# 35        유형자산회전율   2.859476e-05  hetero
# 36        총자본투자효율   1.510000e-36  hetero
# 37         설비투자효율   2.160545e-54  hetero
# 38         기계투자효율   5.037434e-59  hetero
# 39          부가가치율  3.266884e-254  hetero
# 40        노동소득분배율  8.944541e-217  hetero
# 41       인건비(백만원)  2.038032e-115  hetero
# 42      금융비용(백만원)   2.300090e-10  hetero
# 43       임차료(백만원)   3.697088e-31  hetero
# 44     세금과공과(백만원)   7.924970e-74  hetero
# 45     감가상각비(백만원)  3.103048e-125  hetero
# 46   부채대비영업활동현금흐름   4.277293e-27  hetero
# 47   자본대비영업활동현금흐름   2.517394e-35  hetero
# 48  매출액대비영업활동현금흐름   0.000000e+00  hetero
# 49    3년지수가중평균매출액  1.629029e-109  hetero
# 50             업력   1.323187e-01    homo
# 51          연 변동성   1.836165e-08  hetero
# 52            PER   1.393873e-01    homo
# 53            PBR   1.750194e-51  hetero

# %%
c[c["분산"]=='homo']
# Out:
#              피처값    F-test    분산 T-test
# 3        재고자산증가율  0.670690  homo
# 11  매출원가 대 매출액비율  0.184179  homo
# 50            업력  0.132319  homo
# 52           PER  0.139387  homo

# %%
# homo 인 feature 는 student t-test, hetero이면 Welchs T-Test 진행
c["분산"] =''
c["T-test"] =""
for i in c.index:
    if c.loc[i,"F-test"]>=0.05:
        c.loc[i,"분산"] = "homo"
        result = stats.ttest_ind(Bad[c.loc[i,"피처값"]], Good[c.loc[i,"피처값"]], equal_var=True)       ## equal_var = True Student T-test
        c.loc[i,"T-test"] = result[-1]
        print(Bad[c.loc[i,"피처값"]])
    else:
        c.loc[i,"분산"] = "hetero"
        result = stats.ttest_ind(Bad[c.loc[i,"피처값"]], Good[c.loc[i,"피처값"]], equal_var=False)      ## equal_var = False Welchs T-Test
        c.loc[i,"T-test"] = result[-1]
c
# Out:
# 회사명
# 서울식품공업(주)    -0.254125
# (주)원익        -0.146205
# (주)제이테크놀로지   -2.888779
# 더라미(주)       -0.875578
# 페이퍼코리아(주)     0.239934
#                 ...
# 에스유홀딩스(주)     8.387129
# 케이지모빌리티(주)   -0.106271
# (주)메타랩스      -2.353465
# (주)해피드림      -2.100000
# (주)에스코넥      -0.129373
# Name: 재고자산증가율, Length: 638, dtype: float64
# 회사명
# 서울식품공업(주)     0.000842
# (주)원익        -0.106061
# (주)제이테크놀로지   -0.924663
# 더라미(주)        0.900673
# 페이퍼코리아(주)     0.885522
#                 ...
# 에스유홀딩스(주)    -0.134680
# 케이지모빌리티(주)    0.554293
# (주)메타랩스      -0.439815
# (주)해피드림       0.065657
# (주)에스코넥       0.630051
# Name: 매출원가 대 매출액비율, Length: 638, dtype: float64
# 회사명
# 서울식품공업(주)     1.125000
# (주)원익         0.166667
# (주)제이테크놀로지   -0.458333
# 더라미(주)        0.083333
# 페이퍼코리아(주)     1.458333
#                 ...
# 에스유홀딩스(주)     0.333333
# 케이지모빌리티(주)    1.250000
# (주)메타랩스      -0.416667
# (주)해피드림      -0.333333
# (주)에스코넥      -0.250000
# Name: 업력, Length: 638, dtype: float64
# 회사명
# 서울식품공업(주)     3.946770
# (주)원익        -0.381395
# (주)제이테크놀로지   -0.601034
# 더라미(주)       -0.601034
# 페이퍼코리아(주)    -0.601034
#                 ...
# 에스유홀딩스(주)    -0.601034
# 케이지모빌리티(주)   -0.601034
# (주)메타랩스      -0.601034
# (주)해피드림      -0.601034
# (주)에스코넥      -0.601034
# Name: PER, Length: 638, dtype: float64
#               피처값         F-test      분산    T-test
# 0          총자본증가율   1.568630e-56  hetero       0.0
# 1         유형자산증가율   2.148733e-47  hetero  0.890251
# 2         유동자산증가율   2.511731e-36  hetero  0.000002
# 3         재고자산증가율   6.706899e-01    homo  0.001007
# 4         자기자본증가율  1.501459e-123  hetero       0.0
# 5          매출액증가율   6.404316e-55  hetero  0.014121
# 6      매출액정상영업이익률   0.000000e+00  hetero       0.0
# 7         매출액순이익률   0.000000e+00  hetero       0.0
# 8        자기자본순이익률   0.000000e+00  hetero       0.0
# 9         자본금순이익률   1.726543e-68  hetero       0.0
# 10         기업순이익률  7.142701e-201  hetero       0.0
# 11   매출원가 대 매출액비율   1.841786e-01    homo       0.0
# 12   금융비용 대 총비용비율  9.014015e-113  hetero       0.0
# 13          감가상각률   3.272828e-09  hetero  0.218007
# 14       차입금평균이자율   9.197473e-23  hetero       0.0
# 15          사내유보율   1.661129e-33  hetero       0.0
# 16          평균배당률  2.268314e-292  hetero       0.0
# 17        자기자본배당률   1.184798e-77  hetero       0.0
# 18           배당성향   1.956458e-12  hetero       0.0
# 19       자기자본구성비율   1.042644e-05  hetero       0.0
# 20          비유동비율  5.641854e-188  hetero       0.0
# 21       비유동장기적합률   1.377203e-69  hetero       0.0
# 22           유동비율   3.483800e-06  hetero  0.000154
# 23           당좌비율   3.225781e-08  hetero  0.001512
# 24           현금비율   4.548902e-02  hetero  0.000731
# 25  매출채권 대 매입채무비율   1.149270e-13  hetero   0.21288
# 26           부채비율  2.570934e-139  hetero       0.0
# 27         유동부채비율  5.249467e-156  hetero       0.0
# 28        비유동부채비율   1.108015e-93  hetero       0.0
# 29         차입금의존도   5.363747e-16  hetero       0.0
# 30        자기자본회전률   9.283453e-07  hetero  0.299369
# 31         자본금회전률  2.345232e-113  hetero       0.0
# 32        매입채무회전률   2.074151e-36  hetero  0.012581
# 33        재고자산회전률   8.397081e-72  hetero  0.000713
# 34       비유동자산회전률   4.338679e-08  hetero       0.0
# 35        유형자산회전율   2.859476e-05  hetero  0.044163
# 36        총자본투자효율   1.510000e-36  hetero       0.0
# 37         설비투자효율   2.160545e-54  hetero       0.0
# 38         기계투자효율   5.037434e-59  hetero  0.019361
# 39          부가가치율  3.266884e-254  hetero       0.0
# 40        노동소득분배율  8.944541e-217  hetero       0.0
# 41       인건비(백만원)  2.038032e-115  hetero       0.0
# 42      금융비용(백만원)   2.300090e-10  hetero  0.848642
# 43       임차료(백만원)   3.697088e-31  hetero  0.007483
# 44     세금과공과(백만원)   7.924970e-74  hetero  0.000024
# 45     감가상각비(백만원)  3.103048e-125  hetero       0.0
# 46   부채대비영업활동현금흐름   4.277293e-27  hetero       0.0
# 47   자본대비영업활동현금흐름   2.517394e-35  hetero       0.0
# 48  매출액대비영업활동현금흐름   0.000000e+00  hetero       0.0
# 49    3년지수가중평균매출액  1.629029e-109  hetero       0.0
# 50             업력   1.323187e-01    homo  0.000039
# 51          연 변동성   1.836165e-08  hetero       0.0
# 52            PER   1.393873e-01    homo  0.002132
# 53            PBR   1.750194e-51  hetero  0.000025

# %%
# 0.05 이상이면 유의미하지 않으므로 0.05 이하인 것만 추출
d = c[c["T-test"]<= 0.0000005]
print(d.sort_values('T-test',ascending=False)["피처값"].unique())
print('count :',d.sort_values('T-test',ascending=False)["피처값"].nunique())
# d.sort_values('T-test',ascending=False)["피처값"]
# Out:
# ['총자본증가율' '노동소득분배율' '차입금평균이자율' '자기자본증가율' '감가상각비(백만원)' '비유동부채비율'
#  '3년지수가중평균매출액' '매출원가 대 매출액비율' '부채비율' '유동부채비율' '사내유보율' '인건비(백만원)' '비유동비율'
#  '비유동자산회전률' '배당성향' '설비투자효율' '비유동장기적합률' '연 변동성' '자기자본구성비율' '매출액대비영업활동현금흐름'
#  '부가가치율' '매출액순이익률' '금융비용 대 총비용비율' '차입금의존도' '자본대비영업활동현금흐름' '매출액정상영업이익률'
#  '총자본투자효율' '자기자본순이익률' '기업순이익률' '자본금회전률' '자본금순이익률' '부채대비영업활동현금흐름' '평균배당률'
#  '자기자본배당률']
# count : 34

# %%
t_test_feature = d.sort_values('T-test',ascending=True).dropna().iloc[:20,0].tolist()

# %% [markdown]
# ### logit

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
import statsmodels.api as sm
import numpy as np
lr_clf = LogisticRegression()

feature = df_scaled.drop('label',axis=1)
target = df_scaled['label']

logit = SelectFromModel(LogisticRegression())
logit.fit(feature, target)
logit_support = logit.get_support()
lr_feature = feature.loc[:,logit_support].columns.tolist()

# %%
print(lr_feature)
print('count : ',len(lr_feature))
# Out:
# ['유형자산증가율', '재고자산증가율', '매출액정상영업이익률', '매출액순이익률', '자본금순이익률', '평균배당률', '배당성향', '유동비율', '당좌비율', '현금비율', '매출채권 대 매입채무비율', '자본금회전률', '매입채무회전률', '비유동자산회전률', '유형자산회전율', '설비투자효율', '인건비(백만원)', '감가상각비(백만원)', '부채대비영업활동현금흐름', '매출액대비영업활동현금흐름', '3년지수가중평균매출액', 'PER']
# count :  22

# %% [markdown]
# ### Lasso

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import Lasso

# %%
# 12개 피처로 조정 C 값 조정
lasso = SelectFromModel(LogisticRegression(C=0.02, penalty='l1',solver='liblinear'))
lasso.fit(feature, target)
lasso_support = lasso.get_support()
lasso_feature = feature.loc[:,lasso_support].columns.tolist()

# %%
print(lasso_feature)
print('count : ',len(lasso_feature))
# Out:
# ['유형자산증가율', '재고자산증가율', '매출액증가율', '매출액정상영업이익률', '매출액순이익률', '자기자본순이익률', '기업순이익률', '매출원가 대 매출액비율', '금융비용 대 총비용비율', '차입금평균이자율', '사내유보율', '평균배당률', '자기자본배당률', '배당성향', '매출채권 대 매입채무비율', '차입금의존도', '자본금회전률', '매입채무회전률', '재고자산회전률', '비유동자산회전률', '설비투자효율', '인건비(백만원)', '금융비용(백만원)', '임차료(백만원)', '세금과공과(백만원)', '감가상각비(백만원)', '부채대비영업활동현금흐름', 'PER']
# count :  28

# %% [markdown]
# ### 후진제거법

# %%
def backward_regression(X, y,
                           initial_list=[], 
                           threshold_out = 0.05, # P-value 임계값 (제거 기준)
                           feature_list = num_list
                           ):
    
    
    sv_per_step = [] ## 각 스텝별로 선택된 변수들
    adj_r_squared_list = [] ## 각 스텝별 수정된 결정계수
    steps = [] ## 스텝
    step = 0
    included = feature_list
    while True:
        changed=False
        model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[feature_list]))).fit(disp=0)
        # use all coefs except intercept
        pvalues = model.pvalues.iloc[1:] # 각 feature의 P값을 의미함
        worst_pval = pvalues.max()	# P 값이 가장 높은 것 선정
        if worst_pval > threshold_out:
            changed=True
            worst_feature = pvalues.idxmax()
            included.remove(worst_feature)
        
        step += 1
        steps.append(step)        
        adj_r_squared = sm.OLS(y, sm.add_constant(pd.DataFrame(X[feature_list]))).fit(disp=0).rsquared_adj
        adj_r_squared_list.append(adj_r_squared)
        sv_per_step.append(included.copy())
        
        if not changed:
            break
      
    return included,step,steps,adj_r_squared_list,sv_per_step

backward_valriables_function,step,steps,adj_r_squared_list,sv_per_step = backward_regression(feature, target)

# %%
print(backward_valriables_function)
print('count :',len(backward_valriables_function))
# Out:
# ['재고자산증가율', '매출액증가율', '매출액정상영업이익률', '매출액순이익률', '자기자본순이익률', '자본금순이익률', '기업순이익률', '금융비용 대 총비용비율', '차입금평균이자율', '배당성향', '비유동장기적합률', '당좌비율', '차입금의존도', '자기자본회전률', '자본금회전률', '총자본투자효율', '부가가치율', 'PER', 'PBR']
# count : 19

# %% [markdown]
# ### T-test / Lasso / Logit / 후진제거법을 통한 후보피쳐

# %%
from collections import Counter

# 모든 리스트를 하나로 결합
combined_list = t_test_feature + lasso_feature + lr_feature + backward_valriables_function

# 항목의 등장 횟수 계산
item_count = Counter(combined_list)

# 두 번 이상 등장하는 항목 찾기
duplicates = [item for item, count in item_count.items() if count > 1]

print(duplicates)
print('count : ' ,len(duplicates))
# Out:
# ['자기자본배당률', '평균배당률', '부채대비영업활동현금흐름', '자본금순이익률', '자본금회전률', '기업순이익률', '자기자본순이익률', '총자본투자효율', '매출액정상영업이익률', '차입금의존도', '금융비용 대 총비용비율', '매출액순이익률', '부가가치율', '매출액대비영업활동현금흐름', '비유동장기적합률', '설비투자효율', '배당성향', '유형자산증가율', '재고자산증가율', '매출액증가율', '차입금평균이자율', '매출채권 대 매입채무비율', '매입채무회전률', '비유동자산회전률', '인건비(백만원)', '감가상각비(백만원)', 'PER', '당좌비율']
# count :  28

# %% [markdown]
# ### VIF, Corr, 도메인을 통한 최종피쳐 선택

# %%
def vif(data):
    import pandas as pd
    from statsmodels.stats.outliers_influence import variance_inflation_factor

    # VIF 출력을 위한 데이터 프레임 형성
    vif = pd.DataFrame()

    # VIF 값과 각 Feature 이름에 대해 설정
    vif["VIF Factor"] = [variance_inflation_factor(data.values, i) for i in range(len(data.columns))]
    vif["features"] = data.columns 
                    
    # VIF 값이 높은 순으로 정렬
    vif = vif.sort_values(by="VIF Factor", ascending=False)
    vif = vif.reset_index().drop(columns='index')
    
    return vif

# %%
vif(df_scaled[duplicates])
# Out:
#     VIF Factor       features
# 0     9.069030        매출액순이익률
# 1     7.888304         기업순이익률
# 2     5.573090     매출액정상영업이익률
# 3     5.540261          부가가치율
# 4     5.487846       인건비(백만원)
# 5     5.260956     감가상각비(백만원)
# 6     4.818325       자기자본순이익률
# 7     3.542898        자본금순이익률
# 8     3.483666          평균배당률
# 9     3.300518        총자본투자효율
# 10    2.752367  매출액대비영업활동현금흐름
# 11    2.593305   부채대비영업활동현금흐름
# 12    2.581168         자본금회전률
# 13    2.348999         차입금의존도
# 14    2.302267   금융비용 대 총비용비율
# 15    2.240658  매출채권 대 매입채무비율
# 16    2.240402        매입채무회전률
# 17    2.230810        자기자본배당률
# 18    2.097815           당좌비율
# 19    2.089035       비유동장기적합률
# 20    1.891072       비유동자산회전률
# 21    1.315239         설비투자효율
# 22    1.209676           배당성향
# 23    1.201410         매출액증가율
# 24    1.139198        재고자산증가율
# 25    1.130621        유형자산증가율
# 26    1.088822       차입금평균이자율
# 27    1.034173            PER

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = df_scaled[duplicates]

# 상관관계 계산
correlation_matrix = df.corr()

# 상관 행렬의 위쪽 삼각형에 대한 마스크 생성
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))

# 히트맵 생성, 마스크 적용
plt.figure(figsize=(8, 6))  # 히트맵 크기 설정
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5, mask=mask)
plt.title('상장_후보피쳐_heatmap')  # 히트맵 제목 설정
plt.savefig('상장_후보피쳐_heatmap.png')
