# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from matplotlib import font_manager, rc
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from scipy.stats.mstats import winsorize
from sklearn.preprocessing import StandardScaler

# 한글 폰트 설정
font_path = "C:/Windows/Fonts/malgun.ttf"  # 한글 폰트 파일 경로
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# 경고 메시지 무시
warnings.filterwarnings('ignore')

# %%
from scipy.stats import norm
from scipy import stats
from statsmodels.formula.api import ols
from scipy.stats import kstest

# %%
col_list = ['총자본증가율', '유형자산증가율', '유동자산증가율',
       '재고자산증가율', '자기자본증가율', '매출액증가율', '매출액영업이익률', '매출액순이익률', '자기자본순이익률',
       '자본금순이익률', '기업순이익률', '매출원가 대 매출액비율', '금융비용 대 총비용비율', '감가상각률',
       '차입금평균이자율', '사내유보율', '평균배당률', '자기자본배당률', '배당성향', '자기자본구성비율', '비유동비율',
       '비유동장기적합률', '유동비율', '당좌비율', '현금비율', '매출채권 대 매입채무비율', '부채비율', '유동부채비율',
       '비유동부채비율', '차입금의존도', '자기자본회전률', '자본금회전률', '매입채무회전률', '재고자산회전률',
       '비유동자산회전률', '유형자산회전율', '총자본투자효율', '설비투자효율', '기계투자효율', '부가가치율',
       '노동소득분배율', '인건비(백만원)', '금융비용(백만원)', '임차료(백만원)', '조세공과(백만원)',
       '감가상각비(백만원)', '부채대비영업활동현금흐름', '자본대비영업활동현금흐름', '매출액대비영업활동현금흐름',
       '3개년가중평균매출액', '업력', 'label']

num_list = ['총자본증가율', '유형자산증가율', '유동자산증가율',
       '재고자산증가율', '자기자본증가율', '매출액증가율', '매출액영업이익률', '매출액순이익률', '자기자본순이익률',
       '자본금순이익률', '기업순이익률', '매출원가 대 매출액비율', '금융비용 대 총비용비율', '감가상각률',
       '차입금평균이자율', '사내유보율', '평균배당률', '자기자본배당률', '배당성향', '자기자본구성비율', '비유동비율',
       '비유동장기적합률', '유동비율', '당좌비율', '현금비율', '매출채권 대 매입채무비율', '부채비율', '유동부채비율',
       '비유동부채비율', '차입금의존도', '자기자본회전률', '자본금회전률', '매입채무회전률', '재고자산회전률',
       '비유동자산회전률', '유형자산회전율', '총자본투자효율', '설비투자효율', '기계투자효율', '부가가치율',
       '노동소득분배율', '인건비(백만원)', '금융비용(백만원)', '임차료(백만원)', '조세공과(백만원)',
       '감가상각비(백만원)', '부채대비영업활동현금흐름', '자본대비영업활동현금흐름', '매출액대비영업활동현금흐름',
       '3개년가중평균매출액', '업력',]

# %%
df_scaled = pd.read_csv('../datasets/비상장_train.csv', index_col = 0)[col_list]

# %% [markdown]
# ### T-test(K-S통계량 검정)

# %%
for j in num_list:
    a = kstest(df_scaled[j],'norm')
    p = a.pvalue
    print(j,a)
# Out:
# 총자본증가율 KstestResult(statistic=0.09951793474163889, pvalue=0.0, statistic_location=-0.5063731170336038, statistic_sign=-1)
# 유형자산증가율 KstestResult(statistic=0.1276831984723492, pvalue=0.0, statistic_location=2.1392203659506763, statistic_sign=-1)
# 유동자산증가율 KstestResult(statistic=0.07345527114370712, pvalue=0.0, statistic_location=-0.5137559357805079, statistic_sign=-1)
# 재고자산증가율 KstestResult(statistic=0.15705842136603226, pvalue=0.0, statistic_location=0.0, statistic_sign=-1)
# 자기자본증가율 KstestResult(statistic=0.15738442160596133, pvalue=0.0, statistic_location=-0.3411626541397533, statistic_sign=-1)
# 매출액증가율 KstestResult(statistic=0.08000738314341704, pvalue=0.0, statistic_location=-0.4041017850360804, statistic_sign=-1)
# 매출액영업이익률 KstestResult(statistic=0.1638776543719201, pvalue=0.0, statistic_location=-0.461851475076297, statistic_sign=-1)
# 매출액순이익률 KstestResult(statistic=0.17184725285715513, pvalue=0.0, statistic_location=-0.3724304715840387, statistic_sign=-1)
# 자기자본순이익률 KstestResult(statistic=0.17427431964050188, pvalue=0.0, statistic_location=-0.4529262086513995, statistic_sign=-1)
# 자본금순이익률 KstestResult(statistic=0.21815684955213113, pvalue=0.0, statistic_location=-0.3021203651317733, statistic_sign=-1)
# 기업순이익률 KstestResult(statistic=0.10167523829518527, pvalue=0.0, statistic_location=-0.4792626728110599, statistic_sign=-1)
# 매출원가 대 매출액비율 KstestResult(statistic=0.22854048869429278, pvalue=0.0, statistic_location=0.5867328840014191, statistic_sign=1)
# 금융비용 대 총비용비율 KstestResult(statistic=0.18224347265790591, pvalue=0.0, statistic_location=-0.47, statistic_sign=-1)
# 감가상각률 KstestResult(statistic=0.17980577315812338, pvalue=0.0, statistic_location=-0.7275603005140371, statistic_sign=-1)
# 차입금평균이자율 KstestResult(statistic=0.09503960449887178, pvalue=0.0, statistic_location=-1.310344827586207, statistic_sign=-1)
# 사내유보율 KstestResult(statistic=0.5, pvalue=0.0, statistic_location=0.0, statistic_sign=-1)
# 평균배당률 KstestResult(statistic=0.5, pvalue=0.0, statistic_location=0.0, statistic_sign=-1)
# 자기자본배당률 KstestResult(statistic=0.5, pvalue=0.0, statistic_location=0.0, statistic_sign=-1)
# 배당성향 KstestResult(statistic=0.5, pvalue=0.0, statistic_location=0.0, statistic_sign=-1)
# 자기자본구성비율 KstestResult(statistic=0.1593638050495388, pvalue=0.0, statistic_location=-0.9970760233918128, statistic_sign=-1)
# 비유동비율 KstestResult(statistic=0.256157113797962, pvalue=0.0, statistic_location=-0.6552384727176641, statistic_sign=-1)
# 비유동장기적합률 KstestResult(statistic=0.1475637200184335, pvalue=0.0, statistic_location=-1.0469395919455928, statistic_sign=-1)
# 유동비율 KstestResult(statistic=0.21636698737361565, pvalue=0.0, statistic_location=-0.7845218352681038, statistic_sign=-1)
# 당좌비율 KstestResult(statistic=0.25856801017841974, pvalue=0.0, statistic_location=-0.6477664464234417, statistic_sign=-1)
# 현금비율 KstestResult(statistic=0.3817604763654938, pvalue=0.0, statistic_location=-0.3008603941160144, statistic_sign=-1)
# 매출채권 대 매입채무비율 KstestResult(statistic=0.3216320366676359, pvalue=0.0, statistic_location=-0.4631399257342977, statistic_sign=-1)
# 부채비율 KstestResult(statistic=0.29851549127561655, pvalue=0.0, statistic_location=-0.5286749136297781, statistic_sign=-1)
# 유동부채비율 KstestResult(statistic=0.30380050158310073, pvalue=0.0, statistic_location=-0.5135008688677984, statistic_sign=-1)
# 비유동부채비율 KstestResult(statistic=0.386689705715034, pvalue=0.0, statistic_location=-0.2879573170731707, statistic_sign=-1)
# 차입금의존도 KstestResult(statistic=0.24812308169587072, pvalue=0.0, statistic_location=-0.6804079898002551, statistic_sign=-1)
# 자기자본회전률 KstestResult(statistic=0.27809985148518596, pvalue=0.0, statistic_location=-0.588495575221239, statistic_sign=-1)
# 자본금회전률 KstestResult(statistic=0.3404044968844877, pvalue=0.0, statistic_location=-0.4113594353890102, statistic_sign=-1)
# 매입채무회전률 KstestResult(statistic=0.2938597924054192, pvalue=0.0, statistic_location=-0.5421436004162331, statistic_sign=-1)
# 재고자산회전률 KstestResult(statistic=0.361826739977817, pvalue=0.0, statistic_location=-0.3535802469135802, statistic_sign=-1)
# 비유동자산회전률 KstestResult(statistic=0.32036919090127036, pvalue=0.0, statistic_location=-0.4666666666666667, statistic_sign=-1)
# 유형자산회전율 KstestResult(statistic=0.3846390072977466, pvalue=0.0, statistic_location=-0.2933194154488517, statistic_sign=-1)
# 총자본투자효율 KstestResult(statistic=0.10748957345274529, pvalue=0.0, statistic_location=-0.6952727272727273, statistic_sign=-1)
# 설비투자효율 KstestResult(statistic=0.3100348964253533, pvalue=0.0, statistic_location=-0.3315319691541684, statistic_sign=-1)
# 기계투자효율 KstestResult(statistic=0.4138070685818245, pvalue=0.0, statistic_location=-0.1202358554786691, statistic_sign=-1)
# 부가가치율 KstestResult(statistic=0.16234048403468698, pvalue=0.0, statistic_location=-0.765133171912833, statistic_sign=-1)
# 노동소득분배율 KstestResult(statistic=0.17791627509722524, pvalue=0.0, statistic_location=-0.9233351986569672, statistic_sign=-1)
# 인건비(백만원) KstestResult(statistic=0.2639813865487723, pvalue=0.0, statistic_location=-0.6311189169261019, statistic_sign=-1)
# 금융비용(백만원) KstestResult(statistic=0.10678223507334744, pvalue=0.0, statistic_location=-0.597561727530058, statistic_sign=-1)
# 임차료(백만원) KstestResult(statistic=0.3963674822712029, pvalue=0.0, statistic_location=-0.2627607826180953, statistic_sign=-1)
# 조세공과(백만원) KstestResult(statistic=0.2827411422891638, pvalue=0.0, statistic_location=-0.5747176263757436, statistic_sign=-1)
# 감가상각비(백만원) KstestResult(statistic=0.32453278126373847, pvalue=0.0, statistic_location=-0.4550607109136504, statistic_sign=-1)
# 부채대비영업활동현금흐름 KstestResult(statistic=0.1351510348033955, pvalue=0.0, statistic_location=-0.4929254039206009, statistic_sign=-1)
# 자본대비영업활동현금흐름 KstestResult(statistic=0.09515124858824503, pvalue=0.0, statistic_location=-0.4509472463829078, statistic_sign=-1)
# 매출액대비영업활동현금흐름 KstestResult(statistic=0.107270733177973, pvalue=0.0, statistic_location=-0.4975922791959109, statistic_sign=-1)
# 3개년가중평균매출액 KstestResult(statistic=0.2696285823245764, pvalue=0.0, statistic_location=-0.6139366888381828, statistic_sign=-1)
# 업력 KstestResult(statistic=0.14198838587545587, pvalue=0.0, statistic_location=-1.0714285714285714, statistic_sign=-1)

# %%
# 부도기업과 정상기업의 피처별 등분산비교 (정규성 가정으로 bartlett)
Bad = df_scaled[df_scaled['label']== 1] #Existing Customer
Good = df_scaled[df_scaled['label']== 0] #Attrited Customer

c = []
for i in df_scaled.drop('label', axis = 1):
    # lresult = stats.levene(close[i], normal[i])
    lresult = stats.bartlett(Bad[i], Good[i])
    c.append([i,lresult[-1]])

c= pd.DataFrame(c)
c.columns=["피처값",'F-test']
c
# Out:
#               피처값         F-test
# 0          총자본증가율   0.000000e+00
# 1         유형자산증가율  2.314654e-275
# 2         유동자산증가율   0.000000e+00
# 3         재고자산증가율   8.499075e-03
# 4         자기자본증가율   0.000000e+00
# 5          매출액증가율   0.000000e+00
# 6        매출액영업이익률   0.000000e+00
# 7         매출액순이익률   0.000000e+00
# 8        자기자본순이익률   0.000000e+00
# 9         자본금순이익률   2.337601e-39
# 10         기업순이익률   0.000000e+00
# 11   매출원가 대 매출액비율   0.000000e+00
# 12   금융비용 대 총비용비율   0.000000e+00
# 13          감가상각률  1.670200e-174
# 14       차입금평균이자율   0.000000e+00
# 15          사내유보율   0.000000e+00
# 16          평균배당률   0.000000e+00
# 17        자기자본배당률   0.000000e+00
# 18           배당성향   0.000000e+00
# 19       자기자본구성비율   1.420041e-31
# 20          비유동비율   0.000000e+00
# 21       비유동장기적합률   0.000000e+00
# 22           유동비율   0.000000e+00
# 23           당좌비율   0.000000e+00
# 24           현금비율   0.000000e+00
# 25  매출채권 대 매입채무비율   4.177423e-19
# 26           부채비율   0.000000e+00
# 27         유동부채비율   0.000000e+00
# 28        비유동부채비율   0.000000e+00
# 29         차입금의존도   0.000000e+00
# 30        자기자본회전률   7.039298e-06
# 31         자본금회전률   0.000000e+00
# 32        매입채무회전률   8.638666e-22
# 33        재고자산회전률  2.234820e-276
# 34       비유동자산회전률  1.957043e-106
# 35        유형자산회전율   2.264750e-46
# 36        총자본투자효율  4.099723e-125
# 37         설비투자효율   8.784912e-67
# 38         기계투자효율   0.000000e+00
# 39          부가가치율   0.000000e+00
# 40        노동소득분배율   0.000000e+00
# 41       인건비(백만원)   0.000000e+00
# 42      금융비용(백만원)   0.000000e+00
# 43       임차료(백만원)  2.217588e-120
# 44      조세공과(백만원)   3.520886e-02
# 45     감가상각비(백만원)  1.045019e-102
# 46   부채대비영업활동현금흐름  4.712929e-310
# 47   자본대비영업활동현금흐름   0.000000e+00
# 48  매출액대비영업활동현금흐름   0.000000e+00
# 49     3개년가중평균매출액   0.000000e+00
# 50             업력   4.360749e-13

# %%
# F-test 결과 0.05 이상이면 homo 0.05 이하이면 hetero
c["분산"] =''
c["T-test"] =""
for i in c.index:
    if c.loc[i,"F-test"]>=0.05:
        c.loc[i,"분산"] = "homo"
    else:
        c.loc[i,"분산"] = "hetero"
c
# Out:
#               피처값         F-test      분산 T-test
# 0          총자본증가율   0.000000e+00  hetero
# 1         유형자산증가율  2.314654e-275  hetero
# 2         유동자산증가율   0.000000e+00  hetero
# 3         재고자산증가율   8.499075e-03  hetero
# 4         자기자본증가율   0.000000e+00  hetero
# 5          매출액증가율   0.000000e+00  hetero
# 6        매출액영업이익률   0.000000e+00  hetero
# 7         매출액순이익률   0.000000e+00  hetero
# 8        자기자본순이익률   0.000000e+00  hetero
# 9         자본금순이익률   2.337601e-39  hetero
# 10         기업순이익률   0.000000e+00  hetero
# 11   매출원가 대 매출액비율   0.000000e+00  hetero
# 12   금융비용 대 총비용비율   0.000000e+00  hetero
# 13          감가상각률  1.670200e-174  hetero
# 14       차입금평균이자율   0.000000e+00  hetero
# 15          사내유보율   0.000000e+00  hetero
# 16          평균배당률   0.000000e+00  hetero
# 17        자기자본배당률   0.000000e+00  hetero
# 18           배당성향   0.000000e+00  hetero
# 19       자기자본구성비율   1.420041e-31  hetero
# 20          비유동비율   0.000000e+00  hetero
# 21       비유동장기적합률   0.000000e+00  hetero
# 22           유동비율   0.000000e+00  hetero
# 23           당좌비율   0.000000e+00  hetero
# 24           현금비율   0.000000e+00  hetero
# 25  매출채권 대 매입채무비율   4.177423e-19  hetero
# 26           부채비율   0.000000e+00  hetero
# 27         유동부채비율   0.000000e+00  hetero
# 28        비유동부채비율   0.000000e+00  hetero
# 29         차입금의존도   0.000000e+00  hetero
# 30        자기자본회전률   7.039298e-06  hetero
# 31         자본금회전률   0.000000e+00  hetero
# 32        매입채무회전률   8.638666e-22  hetero
# 33        재고자산회전률  2.234820e-276  hetero
# 34       비유동자산회전률  1.957043e-106  hetero
# 35        유형자산회전율   2.264750e-46  hetero
# 36        총자본투자효율  4.099723e-125  hetero
# 37         설비투자효율   8.784912e-67  hetero
# 38         기계투자효율   0.000000e+00  hetero
# 39          부가가치율   0.000000e+00  hetero
# 40        노동소득분배율   0.000000e+00  hetero
# 41       인건비(백만원)   0.000000e+00  hetero
# 42      금융비용(백만원)   0.000000e+00  hetero
# 43       임차료(백만원)  2.217588e-120  hetero
# 44      조세공과(백만원)   3.520886e-02  hetero
# 45     감가상각비(백만원)  1.045019e-102  hetero
# 46   부채대비영업활동현금흐름  4.712929e-310  hetero
# 47   자본대비영업활동현금흐름   0.000000e+00  hetero
# 48  매출액대비영업활동현금흐름   0.000000e+00  hetero
# 49     3개년가중평균매출액   0.000000e+00  hetero
# 50             업력   4.360749e-13  hetero

# %%
c[c["분산"]=='homo']
# Out:
# Empty DataFrame
# Columns: [피처값, F-test, 분산, T-test]
# Index: []

# %%
# homo 인 feature 는 student t-test, hetero이면 Welchs T-Test 진행
c["분산"] =''
c["T-test"] =""
for i in c.index:
    if c.loc[i,"F-test"]>=0.05:
        c.loc[i,"분산"] = "homo"
        result = stats.ttest_ind(Bad[c.loc[i,"피처값"]], Good[c.loc[i,"피처값"]], equal_var=True)       ## equal_var = True Student T-test
        c.loc[i,"T-test"] = result[-1]
        print(Bad[c.loc[i,"피처값"]])
    else:
        c.loc[i,"분산"] = "hetero"
        result = stats.ttest_ind(Bad[c.loc[i,"피처값"]], Good[c.loc[i,"피처값"]], equal_var=False)      ## equal_var = False Welchs T-Test
        c.loc[i,"T-test"] = result[-1]
c
# Out:
#               피처값         F-test      분산    T-test
# 0          총자본증가율   0.000000e+00  hetero       0.0
# 1         유형자산증가율  2.314654e-275  hetero  0.007602
# 2         유동자산증가율   0.000000e+00  hetero       0.0
# 3         재고자산증가율   8.499075e-03  hetero  0.000038
# 4         자기자본증가율   0.000000e+00  hetero       0.0
# 5          매출액증가율   0.000000e+00  hetero       0.0
# 6        매출액영업이익률   0.000000e+00  hetero       0.0
# 7         매출액순이익률   0.000000e+00  hetero       0.0
# 8        자기자본순이익률   0.000000e+00  hetero       0.0
# 9         자본금순이익률   2.337601e-39  hetero       0.0
# 10         기업순이익률   0.000000e+00  hetero       0.0
# 11   매출원가 대 매출액비율   0.000000e+00  hetero       0.0
# 12   금융비용 대 총비용비율   0.000000e+00  hetero       0.0
# 13          감가상각률  1.670200e-174  hetero       0.0
# 14       차입금평균이자율   0.000000e+00  hetero       0.0
# 15          사내유보율   0.000000e+00  hetero       0.0
# 16          평균배당률   0.000000e+00  hetero       0.0
# 17        자기자본배당률   0.000000e+00  hetero       0.0
# 18           배당성향   0.000000e+00  hetero       0.0
# 19       자기자본구성비율   1.420041e-31  hetero       0.0
# 20          비유동비율   0.000000e+00  hetero       0.0
# 21       비유동장기적합률   0.000000e+00  hetero       0.0
# 22           유동비율   0.000000e+00  hetero       0.0
# 23           당좌비율   0.000000e+00  hetero       0.0
# 24           현금비율   0.000000e+00  hetero  0.379691
# 25  매출채권 대 매입채무비율   4.177423e-19  hetero  0.000002
# 26           부채비율   0.000000e+00  hetero       0.0
# 27         유동부채비율   0.000000e+00  hetero       0.0
# 28        비유동부채비율   0.000000e+00  hetero       0.0
# 29         차입금의존도   0.000000e+00  hetero       0.0
# 30        자기자본회전률   7.039298e-06  hetero       0.0
# 31         자본금회전률   0.000000e+00  hetero       0.0
# 32        매입채무회전률   8.638666e-22  hetero  0.000705
# 33        재고자산회전률  2.234820e-276  hetero       0.0
# 34       비유동자산회전률  1.957043e-106  hetero       0.0
# 35        유형자산회전율   2.264750e-46  hetero  0.541923
# 36        총자본투자효율  4.099723e-125  hetero       0.0
# 37         설비투자효율   8.784912e-67  hetero  0.917051
# 38         기계투자효율   0.000000e+00  hetero       0.0
# 39          부가가치율   0.000000e+00  hetero       0.0
# 40        노동소득분배율   0.000000e+00  hetero       0.0
# 41       인건비(백만원)   0.000000e+00  hetero       0.0
# 42      금융비용(백만원)   0.000000e+00  hetero       0.0
# 43       임차료(백만원)  2.217588e-120  hetero       0.0
# 44      조세공과(백만원)   3.520886e-02  hetero  0.000001
# 45     감가상각비(백만원)  1.045019e-102  hetero       0.0
# 46   부채대비영업활동현금흐름  4.712929e-310  hetero       0.0
# 47   자본대비영업활동현금흐름   0.000000e+00  hetero  0.000009
# 48  매출액대비영업활동현금흐름   0.000000e+00  hetero       0.0
# 49     3개년가중평균매출액   0.000000e+00  hetero       0.0
# 50             업력   4.360749e-13  hetero       0.0

# %%
# 0.05 이상이면 유의미하지 않으므로 0.05 이하인 것만 추출
d = c[c["T-test"]<= 0.05]
print(d.sort_values('T-test',ascending=False)["피처값"].unique())
print('count :',d.sort_values('T-test',ascending=False)["피처값"].nunique())
# d.sort_values('T-test',ascending=False)["피처값"]
# Out:
# ['유형자산증가율' '매입채무회전률' '재고자산증가율' '자본대비영업활동현금흐름' '매출채권 대 매입채무비율' '조세공과(백만원)'
#  '당좌비율' '유동비율' '비유동자산회전률' '감가상각비(백만원)' '비유동장기적합률' '임차료(백만원)' '재고자산회전률'
#  '유동자산증가율' '감가상각률' '노동소득분배율' '총자본증가율' '자기자본증가율' '매출액증가율' '유동부채비율'
#  '차입금평균이자율' '부가가치율' '부채비율' '기계투자효율' '비유동부채비율' '비유동비율' '자기자본회전률'
#  '금융비용(백만원)' '사내유보율' '인건비(백만원)' '매출원가 대 매출액비율' '매출액순이익률' '매출액대비영업활동현금흐름'
#  '매출액영업이익률' '자본금회전률' '부채대비영업활동현금흐름' '3개년가중평균매출액' '자기자본배당률' '기업순이익률'
#  '자기자본순이익률' '총자본투자효율' '자본금순이익률' '배당성향' '차입금의존도' '금융비용 대 총비용비율' '평균배당률'
#  '자기자본구성비율' '업력']
# count : 48

# %%
t_test_feature = d.sort_values('T-test',ascending=True).dropna().iloc[:20,0].tolist()

# %% [markdown]
# ### logit

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
import statsmodels.api as sm
import numpy as np
lr_clf = LogisticRegression()

feature = df_scaled.drop('label',axis=1)
target = df_scaled['label']

logit = SelectFromModel(LogisticRegression())
logit.fit(feature, target)
logit_support = logit.get_support()
lr_feature = feature.loc[:,logit_support].columns.tolist()

# %%
print(lr_feature)
print('count : ',len(lr_feature))
# Out:
# ['재고자산증가율', '자기자본증가율', '매출액영업이익률', '매출액순이익률', '자본금순이익률', '사내유보율', '평균배당률', '배당성향', '유동비율', '당좌비율', '현금비율', '매출채권 대 매입채무비율', '유동부채비율', '비유동부채비율', '자기자본회전률', '자본금회전률', '매입채무회전률', '재고자산회전률', '비유동자산회전률', '인건비(백만원)', '임차료(백만원)', '조세공과(백만원)', '감가상각비(백만원)', '3개년가중평균매출액']
# count :  24

# %% [markdown]
# ### Lasso

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import Lasso

# %%
# 12개 피처로 조정 C 값 조정
lasso = SelectFromModel(LogisticRegression(C=0.002, penalty='l1',solver='liblinear'))
lasso.fit(feature, target)
lasso_support = lasso.get_support()
lasso_feature = feature.loc[:,lasso_support].columns.tolist()

# %%
print(lasso_feature)
print('count : ',len(lasso_feature))
# Out:
# ['총자본증가율', '유형자산증가율', '유동자산증가율', '재고자산증가율', '자기자본증가율', '매출액증가율', '매출액영업이익률', '매출액순이익률', '자기자본순이익률', '자본금순이익률', '기업순이익률', '금융비용 대 총비용비율', '차입금평균이자율', '사내유보율', '평균배당률', '배당성향', '자기자본구성비율', '비유동비율', '당좌비율', '현금비율', '매출채권 대 매입채무비율', '유동부채비율', '비유동부채비율', '차입금의존도', '자기자본회전률', '자본금회전률', '매입채무회전률', '재고자산회전률', '비유동자산회전률', '유형자산회전율', '부가가치율', '노동소득분배율', '인건비(백만원)', '금융비용(백만원)', '임차료(백만원)', '감가상각비(백만원)', '부채대비영업활동현금흐름', '자본대비영업활동현금흐름', '3개년가중평균매출액']
# count :  39

# %% [markdown]
# ### 후진제거법

# %%
def backward_regression(X, y,
                           initial_list=[], 
                           threshold_out = 0.0000000000000001, # P-value 임계값 (제거 기준)
                           feature_list = num_list
                           ):
    
    
    sv_per_step = [] ## 각 스텝별로 선택된 변수들
    adj_r_squared_list = [] ## 각 스텝별 수정된 결정계수
    steps = [] ## 스텝
    step = 0
    included = feature_list
    while True:
        changed=False
        model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[feature_list]))).fit(disp=0)
        # use all coefs except intercept
        pvalues = model.pvalues.iloc[1:] # 각 feature의 P값을 의미함
        worst_pval = pvalues.max()	# P 값이 가장 높은 것 선정
        if worst_pval > threshold_out:
            changed=True
            worst_feature = pvalues.idxmax()
            included.remove(worst_feature)
        
        step += 1
        steps.append(step)        
        adj_r_squared = sm.OLS(y, sm.add_constant(pd.DataFrame(X[feature_list]))).fit(disp=0).rsquared_adj
        adj_r_squared_list.append(adj_r_squared)
        sv_per_step.append(included.copy())
        
        if not changed:
            break
      
    return included,step,steps,adj_r_squared_list,sv_per_step

backward_valriables_function,step,steps,adj_r_squared_list,sv_per_step = backward_regression(feature, target)

# %%
print(backward_valriables_function)
print('count :',len(backward_valriables_function))
# Out:
# ['자기자본증가율', '매출액증가율', '매출액영업이익률', '자기자본순이익률', '기업순이익률', '금융비용 대 총비용비율', '차입금평균이자율', '자기자본배당률', '배당성향', '자기자본구성비율', '비유동비율', '비유동장기적합률', '당좌비율', '차입금의존도', '자기자본회전률', '부가가치율', '노동소득분배율', '매출액대비영업활동현금흐름']
# count : 18

# %% [markdown]
# ### T-test / Lasso / Logit / 후진제거법을 통한 후보피쳐

# %%
from collections import Counter

# 모든 리스트를 하나로 결합
combined_list = t_test_feature + lasso_feature + lr_feature + backward_valriables_function

# 항목의 등장 횟수 계산
item_count = Counter(combined_list)

# 두 번 이상 등장하는 항목 찾기
duplicates = [item for item, count in item_count.items() if count > 2]

print(duplicates)
print('count : ' ,len(duplicates))
# Out:
# ['차입금의존도', '3개년가중평균매출액', '자기자본구성비율', '배당성향', '자기자본순이익률', '자본금순이익률', '기업순이익률', '평균배당률', '금융비용 대 총비용비율', '자본금회전률', '매출액영업이익률', '매출액순이익률', '인건비(백만원)', '사내유보율', '자기자본증가율', '당좌비율', '자기자본회전률']
# count :  17

# %% [markdown]
# ### VIF, Corr, 도메인을 통한 최종피쳐 선택

# %%
def vif(data):
    import pandas as pd
    from statsmodels.stats.outliers_influence import variance_inflation_factor

    # VIF 출력을 위한 데이터 프레임 형성
    vif = pd.DataFrame()

    # VIF 값과 각 Feature 이름에 대해 설정
    vif["VIF Factor"] = [variance_inflation_factor(data.values, i) for i in range(len(data.columns))]
    vif["features"] = data.columns 
                    
    # VIF 값이 높은 순으로 정렬
    vif = vif.sort_values(by="VIF Factor", ascending=False)
    vif = vif.reset_index().drop(columns='index')
    
    return vif

# %%
vif(df_scaled[duplicates]).to_csv('./비상장외감_후보피쳐_VIF.csv', encoding = 'UTF-8-sig')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = df_scaled[duplicates]

# 상관관계 계산
correlation_matrix = df.corr()

# 상관 행렬의 위쪽 삼각형에 대한 마스크 생성
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))

# 히트맵 생성, 마스크 적용
plt.figure(figsize=(8, 6))  # 히트맵 크기 설정
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5, mask=mask)
plt.title('비상장외감_후보피쳐_heatmap')  # 히트맵 제목 설정
plt.savefig('비상장외감_후보피쳐_heatmap.png')
